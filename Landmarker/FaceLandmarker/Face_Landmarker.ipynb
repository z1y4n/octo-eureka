# %% [markdown]
# # Face Landmarks Detection with MediaPipe Tasks
#
# This notebook shows you how to use MediaPipe Tasks Python API to detect face landmarks from images.

# %% [markdown]
# # Preparation

# %%
# !wget -O face_landmarker_v2_with_blendshapes.task -q https://storage.googleapis.com/mediapipe-models/face_landmarker/face_landmarker/float16/1/face_landmarker.task

# %% [markdown]
# ## Visualization utilities

# %%
#@markdown We implemented some functions to visualize the face landmark detection results. <br/> Run the following cell to activate the functions.
import mediapipe as mp # type: ignore
from mediapipe import solutions # type: ignore
from mediapipe.framework.formats import landmark_pb2 # type: ignore
import numpy as np # type: ignore
import matplotlib.pyplot as plt # type: ignore
import time # type: ignore

def draw_landmarks_on_image(rgb_image, detection_result):
  face_landmarks_list = detection_result.face_landmarks
  annotated_image = np.copy(rgb_image)

  # Loop through the detected faces to visualize.
  for idx in range(len(face_landmarks_list)):
    face_landmarks = face_landmarks_list[idx]

    # Draw the face landmarks.
    face_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
    face_landmarks_proto.landmark.extend([
      landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in face_landmarks
    ])

    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_TESSELATION,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp.solutions.drawing_styles
        .get_default_face_mesh_tesselation_style())
    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_CONTOURS,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp.solutions.drawing_styles
        .get_default_face_mesh_contours_style())
    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_IRISES,
          landmark_drawing_spec=None,
          connection_drawing_spec=mp.solutions.drawing_styles
          .get_default_face_mesh_iris_connections_style())

  return annotated_image

def plot_face_blendshapes_bar_graph(face_blendshapes):
  # Extract the face blendshapes category names and scores.
  face_blendshapes_names = [face_blendshapes_category.category_name for face_blendshapes_category in face_blendshapes]
  face_blendshapes_scores = [face_blendshapes_category.score for face_blendshapes_category in face_blendshapes]
  # The blendshapes are ordered in decreasing score value.
  face_blendshapes_ranks = range(len(face_blendshapes_names))

  fig, ax = plt.subplots(figsize=(12, 12))
  bar = ax.barh(face_blendshapes_ranks, face_blendshapes_scores, label=[str(x) for x in face_blendshapes_ranks])
  ax.set_yticks(face_blendshapes_ranks, face_blendshapes_names)
  ax.invert_yaxis()

  # Label each bar with values
  for score, patch in zip(face_blendshapes_scores, bar.patches):
    plt.text(patch.get_x() + patch.get_width(), patch.get_y(), f"{score:.4f}", va="top")

  ax.set_xlabel('Score')
  ax.set_title("Face Blendshapes")
  plt.tight_layout()
  plt.show()


last_is_blink = False
last_doze_time = 0
last_wake_time = 0
doze_counter = 0
doze_timer = 0
doze_start = 0
is_doze = False
def print_eyes_status(face_blendshapes):
  global last_is_blink
  global last_doze_time
  global last_wake_time
  global doze_counter
  global doze_timer
  global doze_start
  global is_doze
  face_blendshapes_scores = np.array([face_blendshapes_category.score for face_blendshapes_category in face_blendshapes])
  upward_score = face_blendshapes_scores[17] + face_blendshapes_scores[18]
  downward_score = face_blendshapes_scores[11] + face_blendshapes_scores[12]
  leftward_score = face_blendshapes_scores[14] + face_blendshapes_scores[15]
  rightward_score = face_blendshapes_scores[13] + face_blendshapes_scores[16]
  dir_score = np.array([["upward",upward_score], ["downward",downward_score], ["leftward",leftward_score], ["rightward",rightward_score]])
  dir = dir_score[np.argmax(dir_score[:,1])][0]
  #print(dir)
  is_blink = face_blendshapes_scores[9]>0.6 and face_blendshapes_scores[10]>0.6
  if is_blink:
    if not last_is_blink:
      last_doze_time = time.time()
    if last_doze_time != 0 and time.time() > last_doze_time:
      doze_counter += 1
      time.sleep(0.01)
    if doze_counter > 70:
      if not is_doze:
        doze_start = time.time()
      is_doze = True
      last_wake_time = 0

  else:
    if last_is_blink:
      last_wake_time = time.time()
    if last_wake_time != 0 and time.time() > last_wake_time:
      doze_counter -= 1
      time.sleep(0.01)
    if doze_counter < 20:
      doze_counter = 0
      is_doze = False
  doze_timer = time.time() - doze_start    
  last_is_blink = is_blink
  #print(is_blink)
  if is_doze:
    print(f"doze counter {doze_counter}",f"dozing for {doze_timer:.2f}s")
  else:
    print(f"{'blinking' if is_blink else f'looking {dir}'}")

# %% [markdown]
# ## Running inference and visualizing the results
#
# Here are the steps to run face landmark detection using MediaPipe.
#
# Check out the [MediaPipe documentation](https://developers.google.com/mediapipe/solutions/vision/face_landmarker/python) to learn more about configuration options that this task supports.

# %%
# STEP 1: Import the necessary modules.
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# STEP 2: Create an FaceLandmarker object.
base_options = python.BaseOptions(model_asset_path='face_landmarker_v2_with_blendshapes.task')
options = vision.FaceLandmarkerOptions(base_options=base_options,
                                       output_face_blendshapes=True,
                                       output_facial_transformation_matrixes=True,
                                       num_faces=1)
detector = vision.FaceLandmarker.create_from_options(options)

# %%
import cv2 # type: ignore
cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)
# print(ret_cam)
while cap.isOpened():
    success, frame = cap.read()
    if not success:
        continue
    cam_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame)   
    detection_result_cam = detector.detect(cam_image)
    if len(detection_result_cam.face_blendshapes)==0 or len(detection_result_cam.face_landmarks)==0:
        continue
    annotated_image = draw_landmarks_on_image(cam_image.numpy_view(), detection_result_cam)
    cv2.namedWindow('cam', cv2.WINDOW_AUTOSIZE)
    cv2.imshow("cam", annotated_image)
    print_eyes_status(detection_result_cam.face_blendshapes[0])
    if cv2.waitKey(5) & 0xFF == ord('q'): 
        print("Exiting...")          
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# c:\Users\student\.conda\envs\mediapipe\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking downward
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# blinking
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking downward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking downward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# blinking
# blinking
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking downward
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking upward
# looking upward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking downward
# blinking
# blinking
# looking downward
# blinking
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# looking downward
# blinking
# looking downward
# looking leftward
# looking downward
# looking leftward
# blinking
# blinking
# blinking
# looking downward
# blinking
# blinking
# blinking
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# blinking
# looking leftward
# blinking
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# looking downward
# blinking
# blinking
# looking downward
# blinking
# looking downward
# looking downward
# blinking
# blinking
# blinking
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# blinking
# blinking
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# blinking
# blinking
# looking leftward
# looking downward
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking leftward
# looking leftward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# blinking
# blinking
# blinking
# looking downward
# blinking
# blinking
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# doze counter 71 dozing for 0.00s
# doze counter 72 dozing for 0.04s
# doze counter 73 dozing for 0.07s
# doze counter 74 dozing for 0.11s
# doze counter 75 dozing for 0.15s
# doze counter 76 dozing for 0.19s
# doze counter 77 dozing for 0.24s
# doze counter 78 dozing for 0.28s
# doze counter 79 dozing for 0.32s
# doze counter 80 dozing for 0.35s
# doze counter 81 dozing for 0.41s
# doze counter 82 dozing for 0.45s
# doze counter 83 dozing for 0.49s
# doze counter 84 dozing for 0.52s
# doze counter 85 dozing for 0.56s
# doze counter 86 dozing for 0.60s
# doze counter 87 dozing for 0.63s
# doze counter 88 dozing for 0.67s
# doze counter 89 dozing for 0.71s
# doze counter 90 dozing for 0.76s
# doze counter 91 dozing for 0.79s
# doze counter 92 dozing for 0.83s
# doze counter 93 dozing for 0.87s
# doze counter 94 dozing for 0.90s
# doze counter 95 dozing for 0.94s
# doze counter 96 dozing for 0.98s
# doze counter 97 dozing for 1.01s
# doze counter 98 dozing for 1.05s
# doze counter 99 dozing for 1.09s
# doze counter 100 dozing for 1.12s
# doze counter 101 dozing for 1.16s
# doze counter 102 dozing for 1.20s
# doze counter 103 dozing for 1.24s
# doze counter 104 dozing for 1.28s
# doze counter 105 dozing for 1.32s
# doze counter 106 dozing for 1.35s
# doze counter 107 dozing for 1.39s
# doze counter 108 dozing for 1.43s
# doze counter 109 dozing for 1.47s
# doze counter 110 dozing for 1.50s
# doze counter 111 dozing for 1.54s
# doze counter 112 dozing for 1.58s
# doze counter 113 dozing for 1.62s
# doze counter 114 dozing for 1.65s
# doze counter 115 dozing for 1.69s
# doze counter 116 dozing for 1.73s
# doze counter 117 dozing for 1.76s
# doze counter 118 dozing for 1.80s
# doze counter 119 dozing for 1.84s
# doze counter 120 dozing for 1.88s
# doze counter 121 dozing for 1.91s
# doze counter 122 dozing for 1.95s
# doze counter 123 dozing for 1.99s
# doze counter 124 dozing for 2.03s
# doze counter 125 dozing for 2.06s
# doze counter 126 dozing for 2.10s
# doze counter 127 dozing for 2.14s
# doze counter 128 dozing for 2.18s
# doze counter 129 dozing for 2.21s
# doze counter 130 dozing for 2.25s
# doze counter 131 dozing for 2.29s
# doze counter 132 dozing for 2.33s
# doze counter 133 dozing for 2.36s
# doze counter 134 dozing for 2.40s
# doze counter 135 dozing for 2.44s
# doze counter 136 dozing for 2.47s
# doze counter 137 dozing for 2.52s
# doze counter 138 dozing for 2.55s
# doze counter 139 dozing for 2.59s
# doze counter 140 dozing for 2.63s
# doze counter 141 dozing for 2.67s
# doze counter 142 dozing for 2.70s
# doze counter 143 dozing for 2.74s
# doze counter 144 dozing for 2.78s
# doze counter 145 dozing for 2.82s
# doze counter 146 dozing for 2.87s
# doze counter 147 dozing for 2.90s
# doze counter 148 dozing for 2.94s
# doze counter 149 dozing for 2.98s
# doze counter 150 dozing for 3.01s
# doze counter 150 dozing for 3.04s
# doze counter 150 dozing for 3.07s
# doze counter 151 dozing for 3.11s
# doze counter 152 dozing for 3.14s
# doze counter 153 dozing for 3.18s
# doze counter 153 dozing for 3.23s
# doze counter 152 dozing for 3.27s
# doze counter 152 dozing for 3.31s
# doze counter 153 dozing for 3.34s
# doze counter 153 dozing for 3.37s
# doze counter 153 dozing for 3.40s
# doze counter 153 dozing for 3.42s
# doze counter 153 dozing for 3.45s
# doze counter 153 dozing for 3.48s
# doze counter 152 dozing for 3.54s
# doze counter 151 dozing for 3.58s
# doze counter 150 dozing for 3.62s
# doze counter 149 dozing for 3.66s
# doze counter 148 dozing for 3.69s
# doze counter 147 dozing for 3.74s
# doze counter 146 dozing for 3.78s
# doze counter 146 dozing for 3.81s
# doze counter 146 dozing for 3.84s
# doze counter 145 dozing for 3.88s
# doze counter 144 dozing for 3.92s
# doze counter 143 dozing for 3.96s
# doze counter 142 dozing for 3.99s
# doze counter 141 dozing for 4.03s
# doze counter 140 dozing for 4.07s
# doze counter 139 dozing for 4.11s
# doze counter 138 dozing for 4.14s
# doze counter 137 dozing for 4.18s
# doze counter 136 dozing for 4.22s
# doze counter 135 dozing for 4.25s
# doze counter 134 dozing for 4.29s
# doze counter 133 dozing for 4.33s
# doze counter 132 dozing for 4.37s
# doze counter 131 dozing for 4.40s
# doze counter 130 dozing for 4.44s
# doze counter 129 dozing for 4.48s
# doze counter 128 dozing for 4.51s
# doze counter 127 dozing for 4.56s
# doze counter 126 dozing for 4.59s
# doze counter 125 dozing for 4.63s
# doze counter 124 dozing for 4.67s
# doze counter 123 dozing for 4.71s
# doze counter 122 dozing for 4.74s
# doze counter 121 dozing for 4.78s
# doze counter 120 dozing for 4.82s
# doze counter 119 dozing for 4.86s
# doze counter 118 dozing for 4.89s
# doze counter 117 dozing for 4.93s
# doze counter 116 dozing for 4.97s
# doze counter 115 dozing for 5.01s
# doze counter 114 dozing for 5.04s
# doze counter 113 dozing for 5.08s
# doze counter 112 dozing for 5.12s
# doze counter 111 dozing for 5.16s
# doze counter 110 dozing for 5.19s
# doze counter 109 dozing for 5.23s
# doze counter 108 dozing for 5.27s
# doze counter 107 dozing for 5.31s
# doze counter 106 dozing for 5.34s
# doze counter 105 dozing for 5.38s
# doze counter 104 dozing for 5.42s
# doze counter 103 dozing for 5.45s
# doze counter 102 dozing for 5.49s
# doze counter 101 dozing for 5.53s
# doze counter 100 dozing for 5.56s
# doze counter 99 dozing for 5.60s
# doze counter 98 dozing for 5.64s
# doze counter 97 dozing for 5.68s
# doze counter 96 dozing for 5.71s
# doze counter 95 dozing for 5.75s
# doze counter 94 dozing for 5.79s
# doze counter 93 dozing for 5.83s
# doze counter 92 dozing for 5.86s
# doze counter 91 dozing for 5.90s
# doze counter 90 dozing for 5.94s
# doze counter 89 dozing for 6.00s
# doze counter 88 dozing for 6.03s
# doze counter 87 dozing for 6.07s
# doze counter 86 dozing for 6.11s
# doze counter 85 dozing for 6.15s
# doze counter 84 dozing for 6.18s
# doze counter 83 dozing for 6.22s
# doze counter 82 dozing for 6.26s
# doze counter 81 dozing for 6.30s
# doze counter 80 dozing for 6.34s
# doze counter 79 dozing for 6.38s
# doze counter 78 dozing for 6.43s
# doze counter 77 dozing for 6.47s
# doze counter 76 dozing for 6.50s
# doze counter 75 dozing for 6.54s
# doze counter 74 dozing for 6.58s
# doze counter 73 dozing for 6.61s
# doze counter 72 dozing for 6.66s
# doze counter 71 dozing for 6.70s
# doze counter 70 dozing for 6.74s
# doze counter 69 dozing for 6.78s
# doze counter 68 dozing for 6.82s
# doze counter 67 dozing for 6.85s
# doze counter 66 dozing for 6.89s
# doze counter 65 dozing for 6.93s
# doze counter 64 dozing for 6.97s
# doze counter 63 dozing for 7.00s
# doze counter 62 dozing for 7.04s
# doze counter 61 dozing for 7.08s
# doze counter 60 dozing for 7.12s
# doze counter 59 dozing for 7.15s
# doze counter 58 dozing for 7.19s
# doze counter 57 dozing for 7.23s
# doze counter 56 dozing for 7.26s
# doze counter 55 dozing for 7.31s
# doze counter 54 dozing for 7.35s
# doze counter 53 dozing for 7.39s
# doze counter 52 dozing for 7.42s
# doze counter 51 dozing for 7.46s
# doze counter 50 dozing for 7.50s
# doze counter 49 dozing for 7.54s
# doze counter 48 dozing for 7.58s
# doze counter 47 dozing for 7.61s
# doze counter 46 dozing for 7.65s
# doze counter 45 dozing for 7.69s
# doze counter 44 dozing for 7.74s
# doze counter 43 dozing for 7.77s
# doze counter 42 dozing for 7.81s
# doze counter 41 dozing for 7.85s
# doze counter 40 dozing for 7.89s
# doze counter 39 dozing for 7.92s
# doze counter 38 dozing for 7.96s
# doze counter 37 dozing for 8.00s
# doze counter 36 dozing for 8.03s
# doze counter 35 dozing for 8.07s
# doze counter 34 dozing for 8.11s
# doze counter 33 dozing for 8.15s
# doze counter 32 dozing for 8.18s
# doze counter 31 dozing for 8.22s
# doze counter 30 dozing for 8.26s
# doze counter 29 dozing for 8.30s
# doze counter 28 dozing for 8.34s
# doze counter 27 dozing for 8.38s
# doze counter 26 dozing for 8.42s
# doze counter 25 dozing for 8.46s
# doze counter 24 dozing for 8.49s
# doze counter 23 dozing for 8.53s
# doze counter 22 dozing for 8.57s
# doze counter 21 dozing for 8.60s
# doze counter 20 dozing for 8.64s
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# doze counter 71 dozing for 0.00s
# doze counter 72 dozing for 0.04s
# doze counter 73 dozing for 0.08s
# doze counter 74 dozing for 0.11s
# doze counter 75 dozing for 0.15s
# doze counter 76 dozing for 0.19s
# doze counter 77 dozing for 0.22s
# doze counter 78 dozing for 0.26s
# doze counter 79 dozing for 0.30s
# doze counter 80 dozing for 0.34s
# doze counter 81 dozing for 0.38s
# doze counter 82 dozing for 0.42s
# doze counter 83 dozing for 0.45s
# doze counter 84 dozing for 0.51s
# doze counter 85 dozing for 0.55s
# doze counter 86 dozing for 0.59s
# doze counter 87 dozing for 0.62s
# doze counter 88 dozing for 0.66s
# doze counter 89 dozing for 0.70s
# doze counter 90 dozing for 0.73s
# doze counter 91 dozing for 0.77s
# doze counter 92 dozing for 0.81s
# doze counter 93 dozing for 0.84s
# doze counter 94 dozing for 0.88s
# doze counter 95 dozing for 0.95s
# doze counter 96 dozing for 0.98s
# doze counter 97 dozing for 1.02s
# doze counter 98 dozing for 1.06s
# doze counter 99 dozing for 1.09s
# doze counter 100 dozing for 1.13s
# doze counter 101 dozing for 1.18s
# doze counter 102 dozing for 1.22s
# doze counter 103 dozing for 1.26s
# doze counter 104 dozing for 1.29s
# doze counter 105 dozing for 1.34s
# doze counter 106 dozing for 1.38s
# doze counter 107 dozing for 1.42s
# doze counter 108 dozing for 1.45s
# doze counter 109 dozing for 1.49s
# doze counter 110 dozing for 1.53s
# doze counter 111 dozing for 1.57s
# doze counter 112 dozing for 1.60s
# doze counter 112 dozing for 1.63s
# doze counter 112 dozing for 1.66s
# doze counter 112 dozing for 1.69s
# doze counter 112 dozing for 1.71s
# doze counter 113 dozing for 1.75s
# doze counter 113 dozing for 1.78s
# doze counter 113 dozing for 1.80s
# doze counter 113 dozing for 1.83s
# doze counter 112 dozing for 1.89s
# doze counter 111 dozing for 1.93s
# doze counter 110 dozing for 1.96s
# doze counter 109 dozing for 2.00s
# doze counter 108 dozing for 2.04s
# doze counter 107 dozing for 2.10s
# doze counter 106 dozing for 2.14s
# doze counter 105 dozing for 2.18s
# doze counter 104 dozing for 2.21s
# doze counter 103 dozing for 2.25s
# doze counter 102 dozing for 2.29s
# doze counter 101 dozing for 2.33s
# doze counter 100 dozing for 2.36s
# doze counter 99 dozing for 2.40s
# doze counter 98 dozing for 2.44s
# doze counter 97 dozing for 2.47s
# doze counter 96 dozing for 2.51s
# doze counter 95 dozing for 2.55s
# doze counter 94 dozing for 2.58s
# doze counter 93 dozing for 2.62s
# doze counter 92 dozing for 2.66s
# doze counter 91 dozing for 2.71s
# doze counter 90 dozing for 2.75s
# doze counter 89 dozing for 2.79s
# doze counter 88 dozing for 2.83s
# doze counter 88 dozing for 2.85s
# doze counter 89 dozing for 2.89s
# doze counter 90 dozing for 2.93s
# doze counter 91 dozing for 2.97s
# doze counter 92 dozing for 3.00s
# doze counter 93 dozing for 3.04s
# doze counter 94 dozing for 3.08s
# doze counter 95 dozing for 3.12s
# doze counter 96 dozing for 3.16s
# doze counter 97 dozing for 3.20s
# doze counter 98 dozing for 3.23s
# doze counter 99 dozing for 3.27s
# doze counter 100 dozing for 3.31s
# doze counter 101 dozing for 3.34s
# doze counter 102 dozing for 3.38s
# doze counter 103 dozing for 3.42s
# doze counter 104 dozing for 3.45s
# doze counter 105 dozing for 3.49s
# doze counter 106 dozing for 3.53s
# doze counter 107 dozing for 3.57s
# doze counter 108 dozing for 3.60s
# doze counter 109 dozing for 3.64s
# doze counter 110 dozing for 3.68s
# doze counter 111 dozing for 3.72s
# doze counter 112 dozing for 3.75s
# doze counter 113 dozing for 3.79s
# doze counter 114 dozing for 3.83s
# doze counter 115 dozing for 3.87s
# doze counter 116 dozing for 3.90s
# doze counter 117 dozing for 3.94s
# doze counter 118 dozing for 3.98s
# doze counter 119 dozing for 4.02s
# doze counter 120 dozing for 4.06s
# doze counter 121 dozing for 4.10s
# doze counter 122 dozing for 4.13s
# doze counter 123 dozing for 4.17s
# doze counter 124 dozing for 4.21s
# doze counter 125 dozing for 4.24s
# doze counter 126 dozing for 4.29s
# doze counter 127 dozing for 4.33s
# doze counter 128 dozing for 4.36s
# doze counter 129 dozing for 4.40s
# doze counter 130 dozing for 4.44s
# doze counter 131 dozing for 4.48s
# doze counter 131 dozing for 4.50s
# doze counter 130 dozing for 4.54s
# doze counter 129 dozing for 4.58s
# doze counter 128 dozing for 4.62s
# doze counter 127 dozing for 4.65s
# doze counter 126 dozing for 4.69s
# doze counter 125 dozing for 4.73s
# doze counter 124 dozing for 4.77s
# doze counter 123 dozing for 4.80s
# doze counter 122 dozing for 4.84s
# doze counter 121 dozing for 4.88s
# doze counter 120 dozing for 4.92s
# doze counter 119 dozing for 4.96s
# doze counter 118 dozing for 4.99s
# doze counter 117 dozing for 5.03s
# doze counter 116 dozing for 5.07s
# doze counter 115 dozing for 5.10s
# doze counter 114 dozing for 5.14s
# doze counter 113 dozing for 5.19s
# doze counter 112 dozing for 5.23s
# doze counter 111 dozing for 5.26s
# doze counter 110 dozing for 5.30s
# doze counter 109 dozing for 5.34s
# doze counter 108 dozing for 5.37s
# doze counter 107 dozing for 5.42s
# doze counter 106 dozing for 5.45s
# doze counter 105 dozing for 5.49s
# doze counter 104 dozing for 5.53s
# doze counter 103 dozing for 5.57s
# doze counter 102 dozing for 5.60s
# doze counter 101 dozing for 5.64s
# doze counter 100 dozing for 5.68s
# doze counter 99 dozing for 5.72s
# doze counter 98 dozing for 5.76s
# doze counter 97 dozing for 5.80s
# doze counter 96 dozing for 5.84s
# doze counter 95 dozing for 5.88s
# doze counter 94 dozing for 5.92s
# doze counter 93 dozing for 5.95s
# doze counter 92 dozing for 5.99s
# doze counter 91 dozing for 6.03s
# doze counter 90 dozing for 6.06s
# doze counter 89 dozing for 6.10s
# doze counter 88 dozing for 6.14s
# doze counter 87 dozing for 6.18s
# doze counter 86 dozing for 6.21s
# doze counter 85 dozing for 6.25s
# doze counter 84 dozing for 6.29s
# doze counter 83 dozing for 6.33s
# doze counter 82 dozing for 6.36s
# doze counter 81 dozing for 6.40s
# doze counter 80 dozing for 6.44s
# doze counter 79 dozing for 6.47s
# doze counter 78 dozing for 6.51s
# doze counter 77 dozing for 6.55s
# doze counter 76 dozing for 6.58s
# doze counter 75 dozing for 6.62s
# doze counter 74 dozing for 6.66s
# doze counter 73 dozing for 6.70s
# doze counter 72 dozing for 6.73s
# doze counter 71 dozing for 6.78s
# doze counter 70 dozing for 6.81s
# doze counter 69 dozing for 6.85s
# doze counter 68 dozing for 6.89s
# doze counter 67 dozing for 6.93s
# doze counter 66 dozing for 6.96s
# doze counter 65 dozing for 7.01s
# doze counter 64 dozing for 7.05s
# doze counter 63 dozing for 7.09s
# doze counter 62 dozing for 7.13s
# doze counter 61 dozing for 7.16s
# doze counter 60 dozing for 7.20s
# doze counter 59 dozing for 7.24s
# doze counter 58 dozing for 7.28s
# doze counter 57 dozing for 7.32s
# doze counter 56 dozing for 7.36s
# doze counter 55 dozing for 7.39s
# doze counter 54 dozing for 7.43s
# doze counter 53 dozing for 7.47s
# doze counter 52 dozing for 7.51s
# doze counter 51 dozing for 7.55s
# doze counter 50 dozing for 7.59s
# doze counter 49 dozing for 7.62s
# doze counter 48 dozing for 7.66s
# doze counter 47 dozing for 7.70s
# doze counter 46 dozing for 7.74s
# doze counter 45 dozing for 7.77s
# doze counter 44 dozing for 7.81s
# doze counter 43 dozing for 7.85s
# doze counter 42 dozing for 7.89s
# doze counter 41 dozing for 7.93s
# doze counter 40 dozing for 7.96s
# doze counter 39 dozing for 8.00s
# doze counter 38 dozing for 8.04s
# doze counter 37 dozing for 8.08s
# doze counter 36 dozing for 8.11s
# doze counter 35 dozing for 8.17s
# doze counter 34 dozing for 8.21s
# doze counter 33 dozing for 8.25s
# doze counter 32 dozing for 8.29s
# doze counter 31 dozing for 8.33s
# doze counter 30 dozing for 8.36s
# doze counter 29 dozing for 8.40s
# doze counter 28 dozing for 8.44s
# doze counter 27 dozing for 8.48s
# doze counter 26 dozing for 8.52s
# doze counter 25 dozing for 8.55s
# doze counter 24 dozing for 8.59s
# doze counter 23 dozing for 8.63s
# doze counter 22 dozing for 8.66s
# doze counter 21 dozing for 8.70s
# doze counter 20 dozing for 8.74s
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking downward
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# Exiting...

# %% [markdown]
# And print the transformation matrix.

# %%
#(detection_result.facial_transformation_matrixes)
