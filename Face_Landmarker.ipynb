# %% [markdown]
# # Face Landmarks Detection with MediaPipe Tasks
#
# This notebook shows you how to use MediaPipe Tasks Python API to detect face landmarks from images.

# %% [markdown]
# # Preparation

# %%
# !wget -O face_landmarker_v2_with_blendshapes.task -q https://storage.googleapis.com/mediapipe-models/face_landmarker/face_landmarker/float16/1/face_landmarker.task

# %% [markdown]
# ## Visualization utilities

# %%
#@markdown We implemented some functions to visualize the face landmark detection results. <br/> Run the following cell to activate the functions.
import mediapipe as mp # type: ignore
from mediapipe import solutions # type: ignore
from mediapipe.framework.formats import landmark_pb2 # type: ignore
import numpy as np # type: ignore
import matplotlib.pyplot as plt # type: ignore
import time # type: ignore

def draw_landmarks_on_image(rgb_image, detection_result):
  face_landmarks_list = detection_result.face_landmarks
  annotated_image = np.copy(rgb_image)

  # Loop through the detected faces to visualize.
  for idx in range(len(face_landmarks_list)):
    face_landmarks = face_landmarks_list[idx]

    # Draw the face landmarks.
    face_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
    face_landmarks_proto.landmark.extend([
      landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in face_landmarks
    ])

    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_TESSELATION,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp.solutions.drawing_styles
        .get_default_face_mesh_tesselation_style())
    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_CONTOURS,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp.solutions.drawing_styles
        .get_default_face_mesh_contours_style())
    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_IRISES,
          landmark_drawing_spec=None,
          connection_drawing_spec=mp.solutions.drawing_styles
          .get_default_face_mesh_iris_connections_style())

  return annotated_image

def plot_face_blendshapes_bar_graph(face_blendshapes):
  # Extract the face blendshapes category names and scores.
  face_blendshapes_names = [face_blendshapes_category.category_name for face_blendshapes_category in face_blendshapes]
  face_blendshapes_scores = [face_blendshapes_category.score for face_blendshapes_category in face_blendshapes]
  # The blendshapes are ordered in decreasing score value.
  face_blendshapes_ranks = range(len(face_blendshapes_names))

  fig, ax = plt.subplots(figsize=(12, 12))
  bar = ax.barh(face_blendshapes_ranks, face_blendshapes_scores, label=[str(x) for x in face_blendshapes_ranks])
  ax.set_yticks(face_blendshapes_ranks, face_blendshapes_names)
  ax.invert_yaxis()

  # Label each bar with values
  for score, patch in zip(face_blendshapes_scores, bar.patches):
    plt.text(patch.get_x() + patch.get_width(), patch.get_y(), f"{score:.4f}", va="top")

  ax.set_xlabel('Score')
  ax.set_title("Face Blendshapes")
  plt.tight_layout()
  plt.show()


last_is_blink = False
last_doze_time = 0
last_wake_time = 0
doze_counter = 0
doze_timer = 0
doze_start = 0
is_doze = False
def print_eyes_status(face_blendshapes):
  global last_is_blink
  global last_doze_time
  global last_wake_time
  global doze_counter
  global doze_timer
  global doze_start
  global is_doze
  face_blendshapes_scores = np.array([face_blendshapes_category.score for face_blendshapes_category in face_blendshapes])
  upward_score = face_blendshapes_scores[17] + face_blendshapes_scores[18]
  downward_score = face_blendshapes_scores[11] + face_blendshapes_scores[12]
  leftward_score = face_blendshapes_scores[14] + face_blendshapes_scores[15]
  rightward_score = face_blendshapes_scores[13] + face_blendshapes_scores[16]
  dir_score = np.array([["upward",upward_score], ["downward",downward_score], ["leftward",leftward_score], ["rightward",rightward_score]])
  dir = dir_score[np.argmax(dir_score[:,1])][0]
  #print(dir)
  is_blink = face_blendshapes_scores[9]>0.6 and face_blendshapes_scores[10]>0.6
  if is_blink:
    if not last_is_blink:
      last_doze_time = time.time()
    if last_doze_time != 0 and time.time() > last_doze_time:
      doze_counter += 1
      time.sleep(0.01)
    if doze_counter > 70:
      if not is_doze:
        doze_start = time.time()
      is_doze = True
      last_wake_time = 0

  else:
    if last_is_blink:
      last_wake_time = time.time()
    if last_wake_time != 0 and time.time() > last_wake_time:
      doze_counter -= 1
      time.sleep(0.01)
    if doze_counter < 20:
      doze_counter = 0
      is_doze = False
  doze_timer = time.time() - doze_start    
  last_is_blink = is_blink
  #print(is_blink)
  if is_doze:
    print(f"doze counter {doze_counter}",f"dozing for {doze_timer:.2f}s")
  else:
    print(f"{'blinking' if is_blink else f'looking {dir}'}")

# %% [markdown]
# ## Running inference and visualizing the results
#
# Here are the steps to run face landmark detection using MediaPipe.
#
# Check out the [MediaPipe documentation](https://developers.google.com/mediapipe/solutions/vision/face_landmarker/python) to learn more about configuration options that this task supports.

# %%
# STEP 1: Import the necessary modules.
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# STEP 2: Create an FaceLandmarker object.
base_options = python.BaseOptions(model_asset_path='face_landmarker_v2_with_blendshapes.task')
options = vision.FaceLandmarkerOptions(base_options=base_options,
                                       output_face_blendshapes=True,
                                       output_facial_transformation_matrixes=True,
                                       num_faces=1)
detector = vision.FaceLandmarker.create_from_options(options)

# %%
import cv2 # type: ignore
cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)
# print(ret_cam)
while True:
    _, frame = cap.read()
    if frame is None:
        continue
    cam_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame)   
    detection_result_cam = detector.detect(cam_image)
    if len(detection_result_cam.face_blendshapes)==0 or len(detection_result_cam.face_landmarks)==0:
        continue
    annotated_image = draw_landmarks_on_image(cam_image.numpy_view(), detection_result_cam)
    cv2.namedWindow('cam', cv2.WINDOW_AUTOSIZE)
    cv2.imshow("cam", annotated_image)
    print_eyes_status(detection_result_cam.face_blendshapes[0])
    cv2.waitKey(1)
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        print("Exiting...")
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# doze counter 71 dozing for 0.00s
# doze counter 72 dozing for 0.04s
# doze counter 73 dozing for 0.07s
# doze counter 74 dozing for 0.11s
# doze counter 75 dozing for 0.14s
# doze counter 76 dozing for 0.18s
# doze counter 77 dozing for 0.22s
# doze counter 78 dozing for 0.26s
# doze counter 79 dozing for 0.29s
# doze counter 80 dozing for 0.33s
# doze counter 81 dozing for 0.36s
# doze counter 82 dozing for 0.41s
# doze counter 83 dozing for 0.44s
# doze counter 84 dozing for 0.48s
# doze counter 85 dozing for 0.51s
# doze counter 86 dozing for 0.55s
# doze counter 87 dozing for 0.58s
# doze counter 88 dozing for 0.62s
# doze counter 89 dozing for 0.66s
# doze counter 90 dozing for 0.69s
# doze counter 91 dozing for 0.73s
# doze counter 92 dozing for 0.76s
# doze counter 93 dozing for 0.80s
# doze counter 94 dozing for 0.84s
# doze counter 95 dozing for 0.87s
# doze counter 96 dozing for 0.91s
# doze counter 97 dozing for 0.94s
# doze counter 98 dozing for 0.98s
# doze counter 99 dozing for 1.01s
# doze counter 100 dozing for 1.05s
# doze counter 101 dozing for 1.09s
# doze counter 102 dozing for 1.12s
# doze counter 103 dozing for 1.16s
# doze counter 104 dozing for 1.19s
# doze counter 105 dozing for 1.23s
# doze counter 106 dozing for 1.27s
# doze counter 107 dozing for 1.30s
# doze counter 108 dozing for 1.34s
# doze counter 109 dozing for 1.37s
# doze counter 110 dozing for 1.41s
# doze counter 111 dozing for 1.45s
# doze counter 112 dozing for 1.51s
# doze counter 113 dozing for 1.54s
# doze counter 114 dozing for 1.58s
# doze counter 115 dozing for 1.61s
# doze counter 116 dozing for 1.65s
# doze counter 117 dozing for 1.68s
# doze counter 118 dozing for 1.72s
# doze counter 119 dozing for 1.75s
# doze counter 120 dozing for 1.78s
# doze counter 121 dozing for 1.82s
# doze counter 122 dozing for 1.85s
# doze counter 123 dozing for 1.89s
# doze counter 124 dozing for 1.93s
# doze counter 125 dozing for 1.97s
# doze counter 126 dozing for 2.00s
# doze counter 127 dozing for 2.04s
# doze counter 128 dozing for 2.09s
# doze counter 129 dozing for 2.12s
# doze counter 130 dozing for 2.17s
# doze counter 131 dozing for 2.20s
# doze counter 132 dozing for 2.24s
# doze counter 133 dozing for 2.28s
# doze counter 134 dozing for 2.31s
# doze counter 135 dozing for 2.35s
# doze counter 136 dozing for 2.38s
# doze counter 137 dozing for 2.41s
# doze counter 138 dozing for 2.45s
# doze counter 139 dozing for 2.48s
# doze counter 140 dozing for 2.52s
# doze counter 141 dozing for 2.56s
# doze counter 142 dozing for 2.59s
# doze counter 143 dozing for 2.63s
# doze counter 144 dozing for 2.66s
# doze counter 145 dozing for 2.70s
# doze counter 146 dozing for 2.73s
# doze counter 147 dozing for 2.77s
# doze counter 148 dozing for 2.80s
# doze counter 149 dozing for 2.86s
# doze counter 150 dozing for 2.90s
# doze counter 151 dozing for 2.93s
# doze counter 152 dozing for 2.97s
# doze counter 153 dozing for 3.02s
# doze counter 154 dozing for 3.06s
# doze counter 155 dozing for 3.09s
# doze counter 156 dozing for 3.13s
# doze counter 157 dozing for 3.16s
# doze counter 158 dozing for 3.20s
# doze counter 159 dozing for 3.23s
# doze counter 160 dozing for 3.27s
# doze counter 161 dozing for 3.30s
# doze counter 161 dozing for 3.33s
# doze counter 161 dozing for 3.35s
# doze counter 162 dozing for 3.41s
# doze counter 163 dozing for 3.45s
# doze counter 164 dozing for 3.49s
# doze counter 164 dozing for 3.51s
# doze counter 163 dozing for 3.55s
# doze counter 162 dozing for 3.58s
# doze counter 162 dozing for 3.61s
# doze counter 162 dozing for 3.63s
# doze counter 162 dozing for 3.66s
# doze counter 163 dozing for 3.70s
# doze counter 164 dozing for 3.74s
# doze counter 165 dozing for 3.77s
# doze counter 166 dozing for 3.81s
# doze counter 167 dozing for 3.85s
# doze counter 168 dozing for 3.88s
# doze counter 169 dozing for 3.92s
# doze counter 170 dozing for 3.95s
# doze counter 171 dozing for 3.99s
# doze counter 172 dozing for 4.02s
# doze counter 173 dozing for 4.06s
# doze counter 174 dozing for 4.09s
# doze counter 175 dozing for 4.13s
# doze counter 176 dozing for 4.16s
# doze counter 177 dozing for 4.20s
# doze counter 178 dozing for 4.23s
# doze counter 179 dozing for 4.27s
# doze counter 180 dozing for 4.30s
# doze counter 181 dozing for 4.34s
# doze counter 182 dozing for 4.37s
# doze counter 183 dozing for 4.41s
# doze counter 184 dozing for 4.44s
# doze counter 185 dozing for 4.48s
# doze counter 186 dozing for 4.51s
# doze counter 187 dozing for 4.55s
# doze counter 188 dozing for 4.63s
# doze counter 189 dozing for 4.67s
# doze counter 190 dozing for 4.71s
# doze counter 191 dozing for 4.74s
# doze counter 192 dozing for 4.78s
# doze counter 193 dozing for 4.81s
# doze counter 194 dozing for 4.85s
# doze counter 195 dozing for 4.88s
# doze counter 196 dozing for 4.92s
# doze counter 197 dozing for 4.95s
# doze counter 198 dozing for 4.99s
# doze counter 199 dozing for 5.03s
# doze counter 200 dozing for 5.06s
# doze counter 201 dozing for 5.10s
# doze counter 202 dozing for 5.13s
# doze counter 203 dozing for 5.17s
# doze counter 203 dozing for 5.19s
# doze counter 203 dozing for 5.22s
# doze counter 204 dozing for 5.25s
# doze counter 205 dozing for 5.29s
# doze counter 206 dozing for 5.32s
# doze counter 207 dozing for 5.36s
# doze counter 208 dozing for 5.39s
# doze counter 209 dozing for 5.43s
# doze counter 210 dozing for 5.46s
# doze counter 211 dozing for 5.50s
# doze counter 212 dozing for 5.53s
# doze counter 213 dozing for 5.57s
# doze counter 214 dozing for 5.60s
# doze counter 214 dozing for 5.63s
# doze counter 214 dozing for 5.66s
# doze counter 215 dozing for 5.69s
# doze counter 215 dozing for 5.72s
# doze counter 215 dozing for 5.74s
# doze counter 216 dozing for 5.78s
# doze counter 217 dozing for 5.81s
# doze counter 218 dozing for 5.85s
# doze counter 219 dozing for 5.89s
# doze counter 220 dozing for 5.92s
# doze counter 221 dozing for 5.96s
# doze counter 222 dozing for 5.99s
# doze counter 223 dozing for 6.02s
# doze counter 224 dozing for 6.07s
# doze counter 225 dozing for 6.10s
# doze counter 226 dozing for 6.14s
# doze counter 227 dozing for 6.17s
# doze counter 228 dozing for 6.21s
# doze counter 229 dozing for 6.25s
# doze counter 230 dozing for 6.28s
# doze counter 231 dozing for 6.32s
# doze counter 232 dozing for 6.35s
# doze counter 233 dozing for 6.39s
# doze counter 234 dozing for 6.43s
# doze counter 235 dozing for 6.46s
# doze counter 236 dozing for 6.53s
# doze counter 237 dozing for 6.56s
# doze counter 238 dozing for 6.60s
# doze counter 239 dozing for 6.63s
# doze counter 240 dozing for 6.67s
# doze counter 241 dozing for 6.70s
# doze counter 242 dozing for 6.74s
# doze counter 243 dozing for 6.77s
# doze counter 244 dozing for 6.81s
# doze counter 245 dozing for 6.84s
# doze counter 246 dozing for 6.88s
# doze counter 247 dozing for 6.93s
# doze counter 248 dozing for 6.96s
# doze counter 249 dozing for 7.00s
# doze counter 250 dozing for 7.03s
# doze counter 251 dozing for 7.06s
# doze counter 252 dozing for 7.10s
# doze counter 253 dozing for 7.13s
# doze counter 254 dozing for 7.17s
# doze counter 255 dozing for 7.20s
# doze counter 256 dozing for 7.24s
# doze counter 257 dozing for 7.28s
# doze counter 258 dozing for 7.31s
# doze counter 259 dozing for 7.36s
# doze counter 260 dozing for 7.40s
# doze counter 261 dozing for 7.43s
# doze counter 262 dozing for 7.47s
# doze counter 262 dozing for 7.49s
# doze counter 261 dozing for 7.53s
# doze counter 260 dozing for 7.59s
# doze counter 259 dozing for 7.63s
# doze counter 258 dozing for 7.66s
# doze counter 258 dozing for 7.69s
# doze counter 259 dozing for 7.72s
# doze counter 259 dozing for 7.75s
# doze counter 259 dozing for 7.78s
# doze counter 260 dozing for 7.81s
# doze counter 261 dozing for 7.85s
# doze counter 261 dozing for 7.87s
# doze counter 260 dozing for 7.91s
# doze counter 259 dozing for 7.95s
# doze counter 259 dozing for 7.97s
# doze counter 259 dozing for 7.99s
# doze counter 258 dozing for 8.04s
# doze counter 257 dozing for 8.07s
# doze counter 256 dozing for 8.11s
# doze counter 255 dozing for 8.14s
# doze counter 254 dozing for 8.18s
# doze counter 254 dozing for 8.21s
# doze counter 255 dozing for 8.25s
# doze counter 256 dozing for 8.28s
# doze counter 257 dozing for 8.32s
# doze counter 258 dozing for 8.36s
# doze counter 259 dozing for 8.39s
# doze counter 260 dozing for 8.46s
# doze counter 261 dozing for 8.49s
# doze counter 262 dozing for 8.53s
# doze counter 263 dozing for 8.56s
# doze counter 264 dozing for 8.60s
# doze counter 265 dozing for 8.63s
# doze counter 266 dozing for 8.66s
# doze counter 267 dozing for 8.70s
# doze counter 268 dozing for 8.73s
# doze counter 269 dozing for 8.77s
# doze counter 270 dozing for 8.80s
# doze counter 271 dozing for 8.85s
# doze counter 272 dozing for 8.88s
# doze counter 273 dozing for 8.91s
# doze counter 274 dozing for 8.95s
# doze counter 275 dozing for 8.98s
# doze counter 276 dozing for 9.02s
# doze counter 276 dozing for 9.04s
# doze counter 276 dozing for 9.07s
# doze counter 277 dozing for 9.11s
# doze counter 278 dozing for 9.15s
# doze counter 279 dozing for 9.18s
# doze counter 280 dozing for 9.21s
# doze counter 281 dozing for 9.25s
# doze counter 282 dozing for 9.28s
# doze counter 283 dozing for 9.32s
# doze counter 283 dozing for 9.34s
# doze counter 282 dozing for 9.38s
# doze counter 282 dozing for 9.40s
# doze counter 283 dozing for 9.45s
# doze counter 284 dozing for 9.48s
# doze counter 285 dozing for 9.52s
# doze counter 285 dozing for 9.54s
# doze counter 284 dozing for 9.57s
# doze counter 283 dozing for 9.61s
# doze counter 282 dozing for 9.65s
# doze counter 282 dozing for 9.67s
# doze counter 282 dozing for 9.70s
# doze counter 282 dozing for 9.72s
# doze counter 283 dozing for 9.76s
# doze counter 284 dozing for 9.81s
# doze counter 285 dozing for 9.85s
# doze counter 285 dozing for 9.87s
# doze counter 285 dozing for 9.90s
# doze counter 285 dozing for 9.95s
# doze counter 284 dozing for 9.99s
# doze counter 284 dozing for 10.01s
# doze counter 285 dozing for 10.05s
# doze counter 286 dozing for 10.08s
# doze counter 287 dozing for 10.11s
# doze counter 288 dozing for 10.15s
# doze counter 289 dozing for 10.18s
# doze counter 290 dozing for 10.22s
# doze counter 291 dozing for 10.26s
# doze counter 292 dozing for 10.30s
# doze counter 293 dozing for 10.33s
# doze counter 293 dozing for 10.36s
# doze counter 293 dozing for 10.38s
# doze counter 294 dozing for 10.42s
# doze counter 295 dozing for 10.45s
# doze counter 295 dozing for 10.48s
# doze counter 295 dozing for 10.50s
# doze counter 296 dozing for 10.54s
# doze counter 297 dozing for 10.57s
# doze counter 298 dozing for 10.61s
# doze counter 298 dozing for 10.64s
# doze counter 298 dozing for 10.67s
# doze counter 299 dozing for 10.71s
# doze counter 299 dozing for 10.74s
# doze counter 298 dozing for 10.77s
# doze counter 297 dozing for 10.81s
# doze counter 296 dozing for 10.84s
# doze counter 296 dozing for 10.87s
# doze counter 297 dozing for 10.90s
# doze counter 297 dozing for 10.93s
# doze counter 296 dozing for 10.97s
# doze counter 296 dozing for 11.00s
# doze counter 297 dozing for 11.05s
# doze counter 298 dozing for 11.08s
# doze counter 299 dozing for 11.12s
# doze counter 300 dozing for 11.15s
# doze counter 301 dozing for 11.19s
# doze counter 302 dozing for 11.22s
# doze counter 302 dozing for 11.25s
# doze counter 302 dozing for 11.27s
# doze counter 303 dozing for 11.31s
# doze counter 304 dozing for 11.35s
# doze counter 305 dozing for 11.38s
# doze counter 306 dozing for 11.42s
# doze counter 307 dozing for 11.45s
# doze counter 308 dozing for 11.49s
# doze counter 308 dozing for 11.51s
# doze counter 307 dozing for 11.55s
# doze counter 307 dozing for 11.57s
# doze counter 307 dozing for 11.60s
# doze counter 306 dozing for 11.64s
# doze counter 305 dozing for 11.67s
# doze counter 304 dozing for 11.71s
# doze counter 303 dozing for 11.75s
# doze counter 302 dozing for 11.78s
# doze counter 301 dozing for 11.82s
# doze counter 300 dozing for 11.85s
# doze counter 299 dozing for 11.89s
# doze counter 298 dozing for 11.92s
# doze counter 297 dozing for 11.96s
# doze counter 296 dozing for 11.99s
# doze counter 295 dozing for 12.03s
# doze counter 294 dozing for 12.06s
# doze counter 293 dozing for 12.10s
# doze counter 292 dozing for 12.14s
# doze counter 291 dozing for 12.17s
# doze counter 290 dozing for 12.21s
# doze counter 289 dozing for 12.25s
# doze counter 288 dozing for 12.28s
# doze counter 287 dozing for 12.32s
# doze counter 286 dozing for 12.36s
# doze counter 285 dozing for 12.40s
# doze counter 284 dozing for 12.43s
# doze counter 283 dozing for 12.47s
# doze counter 282 dozing for 12.50s
# doze counter 281 dozing for 12.54s
# doze counter 280 dozing for 12.57s
# doze counter 279 dozing for 12.62s
# doze counter 278 dozing for 12.66s
# doze counter 277 dozing for 12.69s
# doze counter 276 dozing for 12.73s
# doze counter 275 dozing for 12.76s
# doze counter 274 dozing for 12.80s
# doze counter 273 dozing for 12.87s
# doze counter 272 dozing for 12.90s
# doze counter 271 dozing for 12.94s
# doze counter 270 dozing for 12.97s
# doze counter 269 dozing for 13.01s
# doze counter 268 dozing for 13.06s
# doze counter 267 dozing for 13.09s
# doze counter 266 dozing for 13.13s
# doze counter 265 dozing for 13.16s
# doze counter 264 dozing for 13.20s
# doze counter 263 dozing for 13.23s
# doze counter 262 dozing for 13.27s
# doze counter 261 dozing for 13.30s
# doze counter 260 dozing for 13.34s
# doze counter 259 dozing for 13.37s
# doze counter 258 dozing for 13.41s
# doze counter 257 dozing for 13.45s
# doze counter 256 dozing for 13.48s
# doze counter 255 dozing for 13.52s
# doze counter 254 dozing for 13.55s
# doze counter 253 dozing for 13.59s
# doze counter 252 dozing for 13.63s
# doze counter 251 dozing for 13.66s
# doze counter 250 dozing for 13.70s
# doze counter 249 dozing for 13.73s
# doze counter 248 dozing for 13.77s
# doze counter 247 dozing for 13.81s
# doze counter 246 dozing for 13.85s
# doze counter 245 dozing for 13.89s
# doze counter 244 dozing for 13.93s
# doze counter 243 dozing for 13.97s
# doze counter 242 dozing for 14.01s
# doze counter 241 dozing for 14.04s
# doze counter 240 dozing for 14.08s
# doze counter 239 dozing for 14.11s
# doze counter 238 dozing for 14.15s
# doze counter 237 dozing for 14.19s
# doze counter 236 dozing for 14.22s
# doze counter 235 dozing for 14.26s
# doze counter 234 dozing for 14.29s
# doze counter 233 dozing for 14.33s
# doze counter 232 dozing for 14.36s
# doze counter 231 dozing for 14.40s
# doze counter 230 dozing for 14.43s
# doze counter 229 dozing for 14.47s
# doze counter 228 dozing for 14.51s
# doze counter 227 dozing for 14.54s
# doze counter 226 dozing for 14.57s
# doze counter 225 dozing for 14.61s
# doze counter 224 dozing for 14.65s
# doze counter 223 dozing for 14.68s
# doze counter 222 dozing for 14.72s
# doze counter 221 dozing for 14.75s
# doze counter 220 dozing for 14.80s
# doze counter 219 dozing for 14.83s
# doze counter 218 dozing for 14.87s
# doze counter 217 dozing for 14.91s
# doze counter 216 dozing for 14.94s
# doze counter 215 dozing for 14.98s
# doze counter 214 dozing for 15.01s
# doze counter 213 dozing for 15.05s
# doze counter 212 dozing for 15.08s
# doze counter 211 dozing for 15.12s
# doze counter 210 dozing for 15.15s
# doze counter 209 dozing for 15.19s
# doze counter 208 dozing for 15.24s
# doze counter 207 dozing for 15.27s
# doze counter 206 dozing for 15.31s
# doze counter 205 dozing for 15.34s
# doze counter 204 dozing for 15.38s
# doze counter 203 dozing for 15.41s
# doze counter 202 dozing for 15.45s
# doze counter 201 dozing for 15.48s
# doze counter 200 dozing for 15.52s
# doze counter 199 dozing for 15.55s
# doze counter 198 dozing for 15.59s
# doze counter 197 dozing for 15.62s
# doze counter 196 dozing for 15.66s
# doze counter 195 dozing for 15.70s
# doze counter 194 dozing for 15.73s
# doze counter 193 dozing for 15.76s
# doze counter 192 dozing for 15.80s
# doze counter 191 dozing for 15.84s
# doze counter 190 dozing for 15.88s
# doze counter 189 dozing for 15.91s
# doze counter 188 dozing for 15.95s
# doze counter 187 dozing for 15.98s
# doze counter 186 dozing for 16.01s
# doze counter 185 dozing for 16.05s
# doze counter 184 dozing for 16.09s
# doze counter 183 dozing for 16.12s
# doze counter 182 dozing for 16.15s
# doze counter 181 dozing for 16.19s
# doze counter 180 dozing for 16.22s
# doze counter 179 dozing for 16.26s
# doze counter 178 dozing for 16.29s
# doze counter 177 dozing for 16.33s
# doze counter 176 dozing for 16.36s
# doze counter 175 dozing for 16.40s
# doze counter 174 dozing for 16.43s
# doze counter 173 dozing for 16.47s
# doze counter 172 dozing for 16.51s
# doze counter 171 dozing for 16.54s
# doze counter 170 dozing for 16.58s
# doze counter 169 dozing for 16.62s
# doze counter 168 dozing for 16.67s
# doze counter 167 dozing for 16.70s
# doze counter 166 dozing for 16.74s
# doze counter 165 dozing for 16.77s
# doze counter 164 dozing for 16.81s
# doze counter 163 dozing for 16.84s
# doze counter 162 dozing for 16.88s
# doze counter 161 dozing for 16.91s
# doze counter 160 dozing for 16.95s
# doze counter 159 dozing for 16.99s
# doze counter 158 dozing for 17.02s
# doze counter 157 dozing for 17.06s
# doze counter 156 dozing for 17.09s
# doze counter 155 dozing for 17.13s
# doze counter 154 dozing for 17.18s
# doze counter 153 dozing for 17.21s
# doze counter 152 dozing for 17.25s
# doze counter 151 dozing for 17.28s
# doze counter 150 dozing for 17.32s
# doze counter 149 dozing for 17.35s
# doze counter 148 dozing for 17.39s
# doze counter 147 dozing for 17.43s
# doze counter 146 dozing for 17.46s
# doze counter 145 dozing for 17.50s
# doze counter 144 dozing for 17.53s
# doze counter 143 dozing for 17.56s
# doze counter 142 dozing for 17.63s
# doze counter 141 dozing for 17.67s
# doze counter 140 dozing for 17.70s
# doze counter 139 dozing for 17.74s
# doze counter 138 dozing for 17.78s
# doze counter 137 dozing for 17.81s
# doze counter 136 dozing for 17.85s
# doze counter 135 dozing for 17.88s
# doze counter 134 dozing for 17.92s
# doze counter 133 dozing for 17.96s
# doze counter 132 dozing for 17.99s
# doze counter 131 dozing for 18.04s
# doze counter 130 dozing for 18.08s
# doze counter 129 dozing for 18.22s
# doze counter 128 dozing for 18.78s
# doze counter 127 dozing for 18.81s
# doze counter 126 dozing for 18.85s
# doze counter 125 dozing for 18.88s
# doze counter 124 dozing for 18.92s
# doze counter 123 dozing for 18.95s
# doze counter 122 dozing for 18.99s
# doze counter 121 dozing for 19.02s
# doze counter 120 dozing for 19.06s
# doze counter 119 dozing for 19.09s
# doze counter 118 dozing for 19.13s
# doze counter 117 dozing for 19.16s
# doze counter 116 dozing for 19.20s
# doze counter 115 dozing for 19.24s
# doze counter 114 dozing for 19.27s
# doze counter 113 dozing for 19.31s
# doze counter 112 dozing for 19.34s
# doze counter 111 dozing for 19.38s
# doze counter 110 dozing for 19.41s
# doze counter 109 dozing for 19.45s
# doze counter 108 dozing for 19.48s
# doze counter 107 dozing for 19.52s
# doze counter 106 dozing for 19.55s
# doze counter 105 dozing for 19.59s
# doze counter 104 dozing for 19.63s
# doze counter 103 dozing for 19.66s
# doze counter 102 dozing for 19.73s
# doze counter 101 dozing for 19.77s
# doze counter 100 dozing for 19.80s
# doze counter 99 dozing for 19.84s
# doze counter 98 dozing for 19.87s
# doze counter 97 dozing for 19.91s
# doze counter 96 dozing for 19.94s
# doze counter 95 dozing for 19.98s
# doze counter 94 dozing for 20.01s
# doze counter 93 dozing for 20.05s
# doze counter 92 dozing for 20.11s
# doze counter 91 dozing for 20.15s
# doze counter 90 dozing for 20.18s
# doze counter 89 dozing for 20.22s
# doze counter 88 dozing for 20.25s
# doze counter 87 dozing for 20.29s
# doze counter 86 dozing for 20.32s
# doze counter 85 dozing for 20.36s
# doze counter 84 dozing for 20.39s
# doze counter 83 dozing for 20.43s
# doze counter 82 dozing for 20.47s
# doze counter 81 dozing for 20.50s
# doze counter 80 dozing for 20.54s
# doze counter 79 dozing for 20.57s
# doze counter 78 dozing for 20.61s
# doze counter 77 dozing for 20.65s
# doze counter 76 dozing for 20.68s
# doze counter 75 dozing for 20.72s
# doze counter 74 dozing for 20.75s
# doze counter 73 dozing for 20.79s
# doze counter 72 dozing for 20.82s
# doze counter 72 dozing for 20.85s
# doze counter 73 dozing for 20.89s
# doze counter 74 dozing for 20.92s
# doze counter 75 dozing for 20.96s
# doze counter 76 dozing for 21.03s
# doze counter 77 dozing for 21.07s
# doze counter 78 dozing for 21.11s
# doze counter 79 dozing for 21.14s
# doze counter 80 dozing for 21.18s
# doze counter 81 dozing for 21.21s
# doze counter 82 dozing for 21.25s
# doze counter 83 dozing for 21.28s
# doze counter 84 dozing for 21.32s
# doze counter 85 dozing for 21.35s
# doze counter 86 dozing for 21.41s
# doze counter 87 dozing for 21.45s
# doze counter 88 dozing for 21.48s
# doze counter 89 dozing for 21.51s
# doze counter 90 dozing for 21.55s
# doze counter 91 dozing for 21.58s
# doze counter 92 dozing for 21.62s
# doze counter 93 dozing for 21.65s
# doze counter 94 dozing for 21.69s
# doze counter 95 dozing for 21.73s
# doze counter 96 dozing for 21.76s
# doze counter 97 dozing for 21.80s
# doze counter 98 dozing for 21.84s
# doze counter 99 dozing for 21.87s
# doze counter 100 dozing for 21.91s
# doze counter 101 dozing for 21.94s
# doze counter 101 dozing for 21.97s
# doze counter 100 dozing for 22.01s
# doze counter 99 dozing for 22.05s
# doze counter 98 dozing for 22.09s
# doze counter 97 dozing for 22.12s
# doze counter 96 dozing for 22.16s
# doze counter 95 dozing for 22.19s
# doze counter 94 dozing for 22.23s
# doze counter 93 dozing for 22.26s
# doze counter 92 dozing for 22.30s
# doze counter 91 dozing for 22.33s
# doze counter 90 dozing for 22.37s
# doze counter 89 dozing for 22.40s
# doze counter 88 dozing for 22.44s
# doze counter 87 dozing for 22.47s
# doze counter 86 dozing for 22.51s
# doze counter 85 dozing for 22.54s
# doze counter 84 dozing for 22.58s
# doze counter 83 dozing for 22.61s
# doze counter 82 dozing for 22.65s
# doze counter 81 dozing for 22.68s
# doze counter 80 dozing for 22.72s
# doze counter 79 dozing for 22.75s
# doze counter 78 dozing for 22.79s
# doze counter 77 dozing for 22.83s
# doze counter 76 dozing for 22.86s
# doze counter 75 dozing for 22.90s
# doze counter 74 dozing for 22.93s
# doze counter 73 dozing for 22.97s
# doze counter 72 dozing for 23.02s
# doze counter 71 dozing for 23.05s
# doze counter 70 dozing for 23.09s
# doze counter 69 dozing for 23.12s
# doze counter 68 dozing for 23.16s
# doze counter 67 dozing for 23.20s
# doze counter 66 dozing for 23.23s
# doze counter 65 dozing for 23.27s
# doze counter 64 dozing for 23.30s
# doze counter 63 dozing for 23.34s
# doze counter 62 dozing for 23.37s
# doze counter 61 dozing for 23.41s
# doze counter 60 dozing for 23.45s
# doze counter 59 dozing for 23.49s
# doze counter 58 dozing for 23.52s
# doze counter 57 dozing for 23.56s
# doze counter 56 dozing for 23.60s
# doze counter 55 dozing for 23.63s
# doze counter 54 dozing for 23.67s
# doze counter 53 dozing for 23.73s
# doze counter 52 dozing for 23.78s
# doze counter 51 dozing for 23.82s
# doze counter 50 dozing for 23.86s
# doze counter 49 dozing for 23.89s
# doze counter 48 dozing for 23.94s
# doze counter 47 dozing for 24.00s
# doze counter 46 dozing for 24.04s
# doze counter 46 dozing for 24.06s
# doze counter 46 dozing for 24.09s
# doze counter 46 dozing for 24.12s
# doze counter 46 dozing for 24.16s
# doze counter 45 dozing for 24.21s
# doze counter 44 dozing for 24.25s
# doze counter 43 dozing for 24.28s
# doze counter 42 dozing for 24.32s
# doze counter 41 dozing for 24.35s
# doze counter 40 dozing for 24.39s
# doze counter 39 dozing for 24.42s
# doze counter 39 dozing for 24.45s
# doze counter 39 dozing for 24.47s
# doze counter 38 dozing for 24.51s
# doze counter 37 dozing for 24.54s
# doze counter 36 dozing for 24.58s
# doze counter 35 dozing for 24.61s
# doze counter 34 dozing for 24.65s
# doze counter 33 dozing for 24.68s
# doze counter 32 dozing for 24.72s
# doze counter 31 dozing for 24.75s
# doze counter 30 dozing for 24.79s
# doze counter 29 dozing for 24.82s
# doze counter 28 dozing for 24.89s
# doze counter 27 dozing for 24.93s
# doze counter 26 dozing for 24.96s
# doze counter 25 dozing for 25.00s
# doze counter 24 dozing for 25.03s
# doze counter 23 dozing for 25.08s
# doze counter 23 dozing for 25.10s
# doze counter 23 dozing for 25.15s
# doze counter 22 dozing for 25.18s
# doze counter 21 dozing for 25.22s
# doze counter 20 dozing for 25.25s
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking rightward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking rightward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking rightward
# looking downward
# looking leftward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# blinking
# blinking
# blinking
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# ...
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking leftward
# looking leftward
# looking leftward
# looking rightward
# looking leftward
# looking rightward
# looking leftward
# looking leftward
# looking leftward
# looking rightward
# looking rightward
# looking rightward
# looking leftward
# looking rightward
# looking leftward
# looking leftward
# looking rightward
# looking leftward
# looking rightward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking downward
# looking downward
# looking downward
# looking downward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking rightward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking upward
# looking leftward
# looking upward
# looking upward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# looking leftward
# Exiting...

# %% [markdown]
# We will also visualize the face blendshapes categories using a bar graph.

# %% [markdown]
# And print the transformation matrix.

# %%
#(detection_result.facial_transformation_matrixes)
